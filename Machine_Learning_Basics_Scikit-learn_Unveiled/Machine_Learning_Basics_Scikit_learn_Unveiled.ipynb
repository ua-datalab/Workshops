# %% [markdown]
# <a href="https://colab.research.google.com/github/ua-datalab/Workshops/blob/main/Machine_Learning_Basics_Scikit-learn_Unveiled/Machine_Learning_Basics_Scikit_learn_Unveiled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Machine Learning Basics: Scikit-Learn Unveiled

# %% [markdown]
# This is a library in the general scipy sphere, alongside libraries like pandas, numpy, ...

# %%
! pip install scipy
from sklearn import linear_model

# %% [markdown]
# try to use penguin dataset for all examples, if possible. many of carlos' notebooks use penguin so pick those examples and toss them here
#
# using pandas dataframes
#
# seaborn

# %%
# import the penguins dataframe etc

# %% [markdown]
# # Basic statistical questions
#
# ## Statistical inference: Is my data normally distributed?
#
# How to assess if your data is normally distributed? We can visualise a historgram, or perform a Shapiro-Wilk test.
#
# First, let us create two data samples:

# %%
import math
import numpy as np
from scipy import stats
import statsmodels.api as sm
import matplotlib.pyplot as plt

# Create a small normally distributed dataset
norm_data = stats.norm.rvs(size = 5000)

#tCreate a uniformally distributed dataset
non_norm_data = stats.uniform.rvs( size=5000)

# %% [markdown]
# Next, let us examine the first set usign the two methods outlined:

# %%
# Plot a histogram

plt.hist(norm_data, edgecolor='black', bins=100)

#Run a Shapiro-Wilk Test for normal distribution:

print(stats.shapiro(norm_data))
# Out:
# ShapiroResult(statistic=0.9995667338371277, pvalue=0.33698102831840515)

# %% [markdown]
# We see that the p-value for the sample is not low enough for us to reject the null hypothesis.

# %%
# Plot a histogram

plt.hist(non_norm_data, edgecolor='black', bins=100)

#Run a Shapiro-Wilk Test for normal distribution:

print(stats.shapiro(non_norm_data))
# Out:
# ShapiroResult(statistic=0.9548476934432983, pvalue=5.4856884453952884e-17)

# %% [markdown]
# #### We can this use in-built functions in SciPy and matplotlib to visualise and examine our dataset

# %% [markdown]
# # Supervised Learning

# %% [markdown]
# Motivating discussion of why we use supervised learning?
#
# We have data that has labels

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# There are a ton of examples here: https://github.com/clizarraga-UAD7/Notebooks/blob/main/machine_learning_algorithms_for_beginners.ipynb

# %% [markdown]
# ## Logistic Regression

# %% [markdown]
# Penguin Dataset- predict sex of penguin based on species and size/body mass!

# %% [markdown]
# ## KNN
#
# Cluster penguins based on physical characteristics (ex. beaklength), and assess if the data clusters around different species?
#
# this is a nice place to do a quick diversion into topics like: bias variance trade off, hyperparameter tuning (if there is time)

# %% [markdown]
# # Unsupervised Learning

# %% [markdown]
# ## Principal Component Analysis

# %% [markdown]
# chat a little bit about what happens to the covariance matrix
#
# how to identify when it doesnt actually collapse the dimensionality of the data?
#
# linearly related, highly correlated, numeric/metric, sample side is large
#
# discuss penguing dataset -- try to find highly correlated features for predicting species

# %% [markdown]
# ## Clustering

# %% [markdown]
# ### K Means
#
# find a good gif of how this algorithm converges
#
# the ultimate positions of the centroids is dependent on the original positions of the centroids

# %% [markdown]
# ![k_means_clustering.png](data:image/png;base64,...)

# %% [markdown]
# # Take Home Examples
#
# try the PCA analysis on a different task: sex, instead of species
#
# go find something in the scikit learn documentation. change an example to use some different argument, or a different method
#
# pandas review
